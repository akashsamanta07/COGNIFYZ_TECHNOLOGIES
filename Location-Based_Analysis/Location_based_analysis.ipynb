# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("../Dataset.csv")
dataset.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dataset.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(dataset["Longitude"], dataset["Latitude"], alpha=0.5)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Restaurant Distribution")
plt.show()

# %%
group = dataset.groupby('City')
count = group.size()

# %%
count.plot(kind='bar', figsize=(10, 6))
plt.title("No of Restaurants")
plt.xlabel("City")
plt.ylabel("No of Restaurants")
plt.show()

# %%
dataset["City"].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Bras�_lia', 'Rio de Janeiro', 'S��o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
len(dataset["City"].unique())
# Out:
# 141

# %%
df = dataset.copy()

# %%
city_count = dict(df["City"].value_counts().sort_values(ascending=False)[:20])
city_count
# Out:
# {'New Delhi': 5473,
#  'Gurgaon': 1118,
#  'Noida': 1080,
#  'Faridabad': 251,
#  'Ghaziabad': 25,
#  'Bhubaneshwar': 21,
#  'Amritsar': 21,
#  'Ahmedabad': 21,
#  'Guwahati': 21,
#  'Lucknow': 21,
#  'Cape Town': 20,
#  'Bras�_lia': 20,
#  'Rio de Janeiro': 20,
#  'S��o Paulo': 20,
#  'Albany': 20,
#  'Athens': 20,
#  'Augusta': 20,
#  'Manchester': 20,
#  'Boise': 20,
#  'Cedar Rapids/Iowa City': 20}

# %%
city = list(city_count.keys())
count= list(city_count.values())
y = np.arange(len(city))
plt.figure(figsize=(15, 5))
plt.bar(y, count, align='center', alpha=0.5)
plt.xticks(y, city, rotation=90)
plt.xlabel("City")
plt.ylabel("No of Restaurants")
plt.title("Top 20 Cities with Most Restaurants")
plt.show()

# %%
locality_count = dict(df['Address'].value_counts().sort_values(ascending=False)[:20])
print(locality_count)
# Out:
# {'Dilli Haat, INA, New Delhi': 11, 'Sector 41, Noida': 11, 'Greater Kailash (GK) 1, New Delhi': 10, 'The Imperial, Janpath, New Delhi': 9, 'Cyber Hub, DLF Cyber City, Gurgaon': 8, 'Food Court, 3rd Floor, Logix City Centre, Sector 32, Near Sector 34, Noida': 8, 'HUDA Market, Sector 56, Gurgaon': 8, 'Palate of Delhi, Dhaula Kuan Metro Station, Chanakyapuri, New Delhi': 8, 'The Lalit, Barakhamba Avenue, Barakhamba Road, New Delhi': 8, 'Unitech Infospace, Sector 21, Gurgaon': 7, 'DLF Phase 1, Gurgaon': 7, 'The Taj Mahal Hotel, 1, Mansingh Road, New Delhi': 7, 'Main Market, Ghitorni, MG Road, New Delhi': 7, '3rd Floor, DLF Mall of India, Sector 18, Noida': 7, 'Le Meridien, Windsor Place, Janpath, New Delhi': 6, 'DLF Phase 3, Gurgaon': 6, 'Sector 51, Noida': 6, '19, Ansari Road, Ring Road, MGM Club, Daryaganj, New Delhi': 6, 'Sector 56, Gurgaon': 6, 'DLF Phase 4, Gurgaon': 6}

# %%
country_count = dict(df['Country Code'].value_counts().sort_values(ascending=False)[:20])
country_count
# Out:
# {1: 8652,
#  216: 434,
#  215: 80,
#  30: 60,
#  214: 60,
#  189: 60,
#  148: 40,
#  208: 34,
#  14: 24,
#  162: 22,
#  94: 21,
#  184: 20,
#  166: 20,
#  191: 20,
#  37: 4}

# %%
city = list(country_count.keys())
count= list(country_count.values())
y= np.arange(len(city))
plt.figure(figsize=(15, 5))
plt.bar(y, count, align='center', alpha=0.5)
plt.xticks(y, city, rotation=90)
plt.xlabel("Country Code")
plt.ylabel("No of Restaurants")
plt.title("Top 20 Countries with Most Restaurants")
plt.show()

# %%
average= {}
for city, count in city_count.items():
  city_df = dataset[dataset['City'] == city]
  average_rating = city_df['Aggregate rating'].mean()
  average[city] = average_rating

sorted_average_ratings = {k: v for k, v in sorted(average.items(), key=lambda item: item[1], reverse=True)}
print("Average Ratings by City:")
for city, average_rating in sorted_average_ratings.items():
  print(city ,"  ",average_rating)
# Out:
# Average Ratings by City:
# Rio de Janeiro    4.265
# Boise    4.26
# Athens    4.200000000000001
# Lucknow    4.195238095238095
# Guwahati    4.19047619047619
# Cedar Rapids/Iowa City    4.165
# Ahmedabad    4.161904761904761
# Augusta    4.13
# Cape Town    4.109999999999999
# Manchester    4.045
# Bhubaneshwar    3.9809523809523806
# Amritsar    3.6857142857142855
# Albany    3.5550000000000006
# S��o Paulo    3.53
# Bras�_lia    3.495
# Ghaziabad    2.852
# Gurgaon    2.651431127012522
# New Delhi    2.4388452402704184
# Noida    2.036203703703704
# Faridabad    1.8669322709163345

# %%
city = list(sorted_average_ratings.keys())
average_ratings = list(sorted_average_ratings.values())
y = np.arange(len(city))
plt.figure(figsize=(15, 5))
plt.bar(y, average_ratings, align="center",color="green", alpha=0.5)
plt.xticks(y, city, rotation=90)
plt.xlabel("City")
plt.ylabel("Average Rating")
plt.title("Average Rating of Restaurants by City")
plt.show()

# %%
cuisines = dataset["Cuisines"].str.split(',').explode().value_counts().sort_values(ascending=False).to_dict()
cuisines
# Out:
# {'North Indian': 2992,
#  ' Chinese': 1880,
#  ' Fast Food': 1314,
#  ' North Indian': 968,
#  'Chinese': 855,
#  ' Mughlai': 780,
#  'Fast Food': 672,
#  'Bakery': 621,
#  'Cafe': 617,
#  ' Italian': 530,
#  ' Desserts': 503,
#  ' Continental': 501,
#  ' South Indian': 374,
#  ' Street Food': 326,
#  'American': 278,
#  'South Indian': 262,
#  'Mithai': 246,
#  'Street Food': 236,
#  'Continental': 235,
#  'Italian': 234,
#  'Pizza': 232,
#  'Mughlai': 215,
#  ' Thai': 205,
#  'Ice Cream': 178,
#  ' Asian': 156,
#  ' Beverages': 150,
#  'Desserts': 150,
#  ' Pizza': 149,
#  ' Burger': 135,
#  ' Mithai': 134,
#  ' Seafood': 125,
#  ' Bakery': 124,
#  ' Mexican': 119,
#  'Burger': 116,
#  ' American': 112,
#  'Biryani': 112,
#  'Raw Meats': 110,
#  ' Healthy Food': 94,
#  ' Salad': 91,
#  ' European': 86,
#  ' Cafe': 86,
#  ' Mediterranean': 84,
#  'Beverages': 79,
#  'Finger Food': 78,
#  'Asian': 77,
#  'Japanese': 72,
#  ' Biryani': 65,
#  ' Japanese': 63,
#  'Mexican': 62,
# ...

# %%
average = {}
for city, count in city_count.items():
  city_df = dataset[dataset['City'] == city]
  average_price = city_df['Price range'].mean()
  average[city] = average_price
sorted_average_price = {k: v for k, v in sorted(average.items(), key=lambda item: item[1], reverse=True)}
print("Average Price by City:")
for city, average_price in sorted_average_price.items():
  print(city,"   ",average_price)
# Out:
# Average Price by City:
# S��o Paulo     3.6
# Rio de Janeiro     3.5
# Cape Town     3.2
# Bras�_lia     3.1
# Manchester     2.7
# Ahmedabad     2.5714285714285716
# Lucknow     2.5714285714285716
# Guwahati     2.5238095238095237
# Augusta     2.15
# Boise     2.05
# Cedar Rapids/Iowa City     2.05
# Bhubaneshwar     1.8571428571428572
# Gurgaon     1.8559928443649374
# Amritsar     1.8095238095238095
# Ghaziabad     1.8
# Albany     1.7
# New Delhi     1.6215969303855289
# Noida     1.6018518518518519
# Athens     1.6
# Faridabad     1.454183266932271

# %%
city= list(sorted_average_price.keys())
average_price = list(sorted_average_price.values())
plt.figure(figsize=(15, 5))
plt.bar(city, average_price, color="green", width=0.5)
plt.xlabel("City")
plt.ylabel("Average Price")
plt.title("Average Price of Restaurants by City")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1.Visualized the geospatial distribution of restaurants on the map using their co-ordinates using Folium and Geopanda libraries.
#
# 2.New Delhi is the city having the highest number of restaurants with a whopping 5473. It is followed by Gurgaon and Noida.
#
# 3.By locality, Dilli Haat, INA, New Delhi has the most number of restaurants. By Country, country code "1", probably North America tops this list.
#
# 4.Among top 20 cities with most restaurants, Rio de Janeiro and Boise have the highest average restaurant ratings of 4.3.
#
# 5.'North Indian' is the most popular cuisine overall, followed by 'Chinese' and 'Fast Food'.
#
# 6.Among the top 20 cities with most restaurants, S��o Paulo and Rio de Janeiro have the most expensive restaurants (average).
