# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("../Dataset.csv")

# %%
dataset.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dataset.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
dataset=dataset[["City","Currency","Average Cost for two","Has Table booking","Has Online delivery","Is delivering now","Switch to order menu","Price range","Aggregate rating","Rating text"]]

# %%
dataset.head(5)
# Out:
#                City          Currency  Average Cost for two Has Table booking  \
# 0       Makati City  Botswana Pula(P)                  1100               Yes
# 1       Makati City  Botswana Pula(P)                  1200               Yes
# 2  Mandaluyong City  Botswana Pula(P)                  4000               Yes
# 3  Mandaluyong City  Botswana Pula(P)                  1500                No
# 4  Mandaluyong City  Botswana Pula(P)                  1500               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
# 2                  No                No                   No            4
# 3                  No                No                   No            4
# 4                  No                No                   No            4
#
#    Aggregate rating Rating text
# ...

# %%
dataset.shape
# Out:
# (9551, 10)

# %%
dataset.columns
# Out:
# Index(['City', 'Currency', 'Average Cost for two', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating text'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   City                  9551 non-null   object
#  1   Currency              9551 non-null   object
#  2   Average Cost for two  9551 non-null   int64
#  3   Has Table booking     9551 non-null   object
#  4   Has Online delivery   9551 non-null   object
#  5   Is delivering now     9551 non-null   object
#  6   Switch to order menu  9551 non-null   object
#  7   Price range           9551 non-null   int64
#  8   Aggregate rating      9551 non-null   float64
#  9   Rating text           9551 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 746.3+ KB

# %%
dataset.describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating
# count           9551.000000  9551.000000       9551.000000
# mean            1199.210763     1.804837          2.666370
# std            16121.183073     0.905609          1.516378
# min                0.000000     1.000000          0.000000
# 25%              250.000000     1.000000          2.500000
# 50%              400.000000     2.000000          3.200000
# 75%              700.000000     2.000000          3.700000
# max           800000.000000     4.000000          4.900000

# %%
sns.boxplot(x="Average Cost for two",data=dataset)
plt.show()

# %%
# q1=dataset["Average Cost for two"].quantile(0.25)
# q3=dataset["Average Cost for two"].quantile(0.75)
# IQR=q3-q1
# minvalue=q1-(IQR*1.5)
# maxvalue=q3+(IQR*1.5)
# dataset[dataset["Average Cost for two"]<=maxvalue]

# %%
import numpy as np

# %%
dataset["City"].unique()
# Out:
# array(['Makati City', 'Mandaluyong City', 'Pasay City', 'Pasig City',
#        'Quezon City', 'San Juan City', 'Santa Rosa', 'Tagaytay City',
#        'Taguig City', 'Bras�_lia', 'Rio de Janeiro', 'S��o Paulo',
#        'Albany', 'Armidale', 'Athens', 'Augusta', 'Balingup',
#        'Beechworth', 'Boise', 'Cedar Rapids/Iowa City', 'Chatham-Kent',
#        'Clatskanie', 'Cochrane', 'Columbus', 'Consort', 'Dalton',
#        'Davenport', 'Des Moines', 'Dicky Beach', 'Dubuque',
#        'East Ballina', 'Fernley', 'Flaxton', 'Forrest', 'Gainesville',
#        'Hepburn Springs', 'Huskisson', 'Inverloch', 'Lakes Entrance',
#        'Lakeview', 'Lincoln', 'Lorn', 'Macedon', 'Macon', 'Mayfield',
#        'Mc Millan', 'Middleton Beach', 'Miller', 'Monroe', 'Montville',
#        'Ojo Caliente', 'Orlando', 'Palm Cove', 'Paynesville', 'Penola',
#        'Pensacola', 'Phillip Island', 'Pocatello', 'Potrero', 'Princeton',
#        'Rest of Hawaii', 'Savannah', 'Singapore', 'Sioux City',
# ...

# %%
np.sort(dataset["City"].unique())
# Out:
# array(['Abu Dhabi', 'Agra', 'Ahmedabad', 'Albany', 'Allahabad',
#        'Amritsar', 'Ankara', 'Armidale', 'Athens', 'Auckland', 'Augusta',
#        'Aurangabad', 'Balingup', 'Bandung', 'Bangalore', 'Beechworth',
#        'Bhopal', 'Bhubaneshwar', 'Birmingham', 'Bogor', 'Boise',
#        'Bras�_lia', 'Cape Town', 'Cedar Rapids/Iowa City', 'Chandigarh',
#        'Chatham-Kent', 'Chennai', 'Clatskanie', 'Cochrane', 'Coimbatore',
#        'Colombo', 'Columbus', 'Consort', 'Dalton', 'Davenport',
#        'Dehradun', 'Des Moines', 'Dicky Beach', 'Doha', 'Dubai',
#        'Dubuque', 'East Ballina', 'Edinburgh', 'Faridabad', 'Fernley',
#        'Flaxton', 'Forrest', 'Gainesville', 'Ghaziabad', 'Goa', 'Gurgaon',
#        'Guwahati', 'Hepburn Springs', 'Huskisson', 'Hyderabad', 'Indore',
#        'Inner City', 'Inverloch', 'Jaipur', 'Jakarta', 'Johannesburg',
#        'Kanpur', 'Kochi', 'Kolkata', 'Lakes Entrance', 'Lakeview',
# ...

# %%
city=[['Abu Dhabi', 'Agra', 'Ahmedabad', 'Albany', 'Allahabad',
       'Amritsar', 'Ankara', 'Armidale', 'Athens', 'Auckland', 'Augusta',
       'Aurangabad', 'Balingup', 'Bandung', 'Bangalore', 'Beechworth',
       'Bhopal', 'Bhubaneshwar', 'Birmingham', 'Bogor', 'Boise',
       'Bras�_lia', 'Cape Town', 'Cedar Rapids/Iowa City', 'Chandigarh',
       'Chatham-Kent', 'Chennai', 'Clatskanie', 'Cochrane', 'Coimbatore',
       'Colombo', 'Columbus', 'Consort', 'Dalton', 'Davenport',
       'Dehradun', 'Des Moines', 'Dicky Beach', 'Doha', 'Dubai',
       'Dubuque', 'East Ballina', 'Edinburgh', 'Faridabad', 'Fernley',
       'Flaxton', 'Forrest', 'Gainesville', 'Ghaziabad', 'Goa', 'Gurgaon',
       'Guwahati', 'Hepburn Springs', 'Huskisson', 'Hyderabad', 'Indore',
       'Inner City', 'Inverloch', 'Jaipur', 'Jakarta', 'Johannesburg',
       'Kanpur', 'Kochi', 'Kolkata', 'Lakes Entrance', 'Lakeview',
       'Lincoln', 'London', 'Lorn', 'Lucknow', 'Ludhiana', 'Macedon',
       'Macon', 'Makati City', 'Manchester', 'Mandaluyong City',
       'Mangalore', 'Mayfield', 'Mc Millan', 'Middleton Beach', 'Miller',
       'Mohali', 'Monroe', 'Montville', 'Mumbai', 'Mysore', 'Nagpur',
       'Nashik', 'New Delhi', 'Noida', 'Ojo Caliente', 'Orlando',
       'Palm Cove', 'Panchkula', 'Pasay City', 'Pasig City', 'Patna',
       'Paynesville', 'Penola', 'Pensacola', 'Phillip Island',
       'Pocatello', 'Potrero', 'Pretoria', 'Princeton', 'Puducherry',
       'Pune', 'Quezon City', 'Ranchi', 'Randburg', 'Rest of Hawaii',
       'Rio de Janeiro', 'San Juan City', 'Sandton', 'Santa Rosa',
       'Savannah', 'Secunderabad', 'Sharjah', 'Singapore', 'Sioux City',
       'Surat', 'S��o Paulo', 'Tagaytay City', 'Taguig City', 'Tampa Bay',
       'Tangerang', 'Tanunda', 'Trentham East', 'Vadodara', 'Valdosta',
       'Varanasi', 'Vernonia', 'Victor Harbor', 'Vineland Station',
       'Vizag', 'Waterloo', 'Weirton', 'Wellington City',
       'Winchester Bay', 'Yorkton', '��stanbul']]

# %%
from sklearn.preprocessing import OrdinalEncoder,LabelEncoder,StandardScaler

# %%
oe_city=OrdinalEncoder(categories=city)
oe_city.fit(dataset[["City"]])
# Out:
# OrdinalEncoder(categories=[['Abu Dhabi', 'Agra', 'Ahmedabad', 'Albany',
#                             'Allahabad', 'Amritsar', 'Ankara', 'Armidale',
#                             'Athens', 'Auckland', 'Augusta', 'Aurangabad',
#                             'Balingup', 'Bandung', 'Bangalore', 'Beechworth',
#                             'Bhopal', 'Bhubaneshwar', 'Birmingham', 'Bogor',
#                             'Boise', 'Bras�_lia', 'Cape Town',
#                             'Cedar Rapids/Iowa City', 'Chandigarh',
#                             'Chatham-Kent', 'Chennai', 'Clatskanie', 'Cochrane',
#                             'Coimbatore', ...]])

# %%
dataset["City"]=oe.transform(dataset[["City"]])

# %%
dataset.head(5)
# Out:
#    City          Currency  Average Cost for two Has Table booking  \
# 0  73.0  Botswana Pula(P)                  1100               Yes
# 1  73.0  Botswana Pula(P)                  1200               Yes
# 2  75.0  Botswana Pula(P)                  4000               Yes
# 3  75.0  Botswana Pula(P)                  1500                No
# 4  75.0  Botswana Pula(P)                  1500               Yes
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
# 2                  No                No                   No            4
# 3                  No                No                   No            4
# 4                  No                No                   No            4
#
#    Aggregate rating Rating text
# 0               4.8   Excellent
# 1               4.5   Excellent
# ...

# %%
sc_act=StandardScaler()

# %%
sc_act.fit(dataset[["Average Cost for two"]])
# Out:
# StandardScaler()

# %%
dataset["Average Cost for two"]=sc_act.transform(dataset[["Average Cost for two"]])

# %%
dataset["Has Table booking"].value_counts()
# Out:
# Has Table booking
# No     8393
# Yes    1158
# Name: count, dtype: int64

# %%
dataset["Has Table booking"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Has Table booking")
plt.plot()
# Out:
# []

# %%
htb=LabelEncoder()
htb.fit(dataset["Has Table booking"])
dataset["Has Table booking"]= htb.transform(dataset["Has Table booking"])

# %%
dataset.head(5)
# Out:
#    City          Currency  Average Cost for two  Has Table booking  \
# 0  73.0  Botswana Pula(P)             -0.006154                  1
# 1  73.0  Botswana Pula(P)              0.000049                  1
# 2  75.0  Botswana Pula(P)              0.173743                  1
# 3  75.0  Botswana Pula(P)              0.018659                  0
# 4  75.0  Botswana Pula(P)              0.018659                  1
#
#   Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                  No                No                   No            3
# 1                  No                No                   No            3
# 2                  No                No                   No            4
# 3                  No                No                   No            4
# 4                  No                No                   No            4
#
#    Aggregate rating Rating text
# 0               4.8   Excellent
# 1               4.5   Excellent
# ...

# %%
dataset["Has Online delivery"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Has Online delivery")
plt.plot()
# Out:
# []

# %%
htb=LabelEncoder()
htb.fit(dataset["Has Online delivery"])
dataset["Has Online delivery"]= htb.transform(dataset["Has Online delivery"])

# %%
dataset.head(5)
# Out:
#    City          Currency  Average Cost for two  Has Table booking  \
# 0  73.0  Botswana Pula(P)             -0.006154                  1
# 1  73.0  Botswana Pula(P)              0.000049                  1
# 2  75.0  Botswana Pula(P)              0.173743                  1
# 3  75.0  Botswana Pula(P)              0.018659                  0
# 4  75.0  Botswana Pula(P)              0.018659                  1
#
#    Has Online delivery Is delivering now Switch to order menu  Price range  \
# 0                    0                No                   No            3
# 1                    0                No                   No            3
# 2                    0                No                   No            4
# 3                    0                No                   No            4
# 4                    0                No                   No            4
#
#    Aggregate rating Rating text
# 0               4.8   Excellent
# 1               4.5   Excellent
# ...

# %%
dataset["Is delivering now"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Is delivering now")
plt.plot()
# Out:
# []

# %%
dataset["Is delivering now"].value_counts()
# Out:
# Is delivering now
# No     9517
# Yes      34
# Name: count, dtype: int64

# %%
dataset["Switch to order menu"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Switch to order menu")
plt.plot()
# Out:
# []

# %%
dataset=dataset.drop(columns=["Is delivering now","Switch to order menu"])

# %%
dataset["Currency"].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(��)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
np.sort(dataset["Currency"].unique())
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(��)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
currency=[['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
       'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
       'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(��)',
       'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
       'Turkish Lira(TL)']]

# %%
oe_currency=OrdinalEncoder()
oe_currency.fit(dataset[["Currency"]])
# Out:
# OrdinalEncoder()

# %%
dataset["Currency"]=oe_currency.transform(dataset[["Currency"]])

# %%
dataset.head(5)
# Out:
#    City  Currency  Average Cost for two  Has Table booking  \
# 0  73.0       0.0             -0.006154                  1
# 1  73.0       0.0              0.000049                  1
# 2  75.0       0.0              0.173743                  1
# 3  75.0       0.0              0.018659                  0
# 4  75.0       0.0              0.018659                  1
#
#    Has Online delivery  Price range  Aggregate rating Rating text
# 0                    0            3               4.8   Excellent
# 1                    0            3               4.5   Excellent
# 2                    0            4               4.4   Very Good
# 3                    0            4               4.9   Excellent
# 4                    0            4               4.8   Excellent

# %%
dataset.groupby("Rating text")["Aggregate rating"].max()
# Out:
# Rating text
# Average      3.4
# Excellent    4.9
# Good         3.9
# Not rated    0.0
# Poor         2.4
# Very Good    4.4
# Name: Aggregate rating, dtype: float64

# %%
dataset.groupby("Rating text")["Aggregate rating"].min()
# Out:
# Rating text
# Average      2.5
# Excellent    4.5
# Good         3.5
# Not rated    0.0
# Poor         1.8
# Very Good    4.0
# Name: Aggregate rating, dtype: float64

# %%
inputdata=dataset.drop(columns=["Aggregate rating","Rating text"])
inputdata
# Out:
#        City  Currency  Average Cost for two  Has Table booking  \
# 0      73.0       0.0             -0.006154                  1
# 1      73.0       0.0              0.000049                  1
# 2      75.0       0.0              0.173743                  1
# 3      75.0       0.0              0.018659                  0
# 4      75.0       0.0              0.018659                  1
# ...     ...       ...                   ...                ...
# 9546  140.0      11.0             -0.069428                  0
# 9547  140.0      11.0             -0.067878                  0
# 9548  140.0      11.0             -0.063845                  0
# 9549  140.0      11.0             -0.066947                  0
# 9550  140.0      11.0             -0.070979                  0
#
#       Has Online delivery  Price range
# 0                       0            3
# 1                       0            3
# 2                       0            4
# 3                       0            4
# ...

# %%
outputdata=dataset["Aggregate rating"]
outputdata
# Out:
# 0       4.8
# 1       4.5
# 2       4.4
# 3       4.9
# 4       4.8
#        ...
# 9546    4.1
# 9547    4.2
# 9548    3.7
# 9549    4.0
# 9550    4.0
# Name: Aggregate rating, Length: 9551, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,r2_score

# %%
model=RandomForestRegressor()

# %%
x_train,x_test,y_train,y_text=train_test_split(inputdata,outputdata,test_size=0.2,random_state=0)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
r2_score(y_text,y_pred)
# Out:
# 0.39002395935655243

# %%
dataset.head(5)
# Out:
#    City  Currency  Average Cost for two  Has Table booking  \
# 0  73.0       0.0             -0.006154                  1
# 1  73.0       0.0              0.000049                  1
# 2  75.0       0.0              0.173743                  1
# 3  75.0       0.0              0.018659                  0
# 4  75.0       0.0              0.018659                  1
#
#    Has Online delivery  Price range  Aggregate rating Rating text
# 0                    0            3               4.8   Excellent
# 1                    0            3               4.5   Excellent
# 2                    0            4               4.4   Very Good
# 3                    0            4               4.9   Excellent
# 4                    0            4               4.8   Excellent
