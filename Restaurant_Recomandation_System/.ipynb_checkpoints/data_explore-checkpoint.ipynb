# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("..//Dataset.csv")
dataset.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dataset.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
dataset.shape
# Out:
# (9551, 21)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
dataset["Rating text"].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
dataset=dataset[dataset["Rating text"] != "Not rated"]
dataset=dataset.reset_index()
dataset=dataset.drop(columns=["index"])
dataset.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
dataset["Aggregate rating"].value_counts()
# Out:
# Aggregate rating
# 3.2    522
# 3.1    519
# 3.4    498
# 3.3    483
# 3.5    480
# 3.0    468
# 3.6    458
# 3.7    427
# 3.8    400
# 2.9    381
# 3.9    335
# 2.8    315
# 4.1    274
# 4.0    266
# 2.7    250
# 4.2    221
# 2.6    191
# 4.3    174
# 4.4    144
# 2.5    110
# 4.5     95
# 2.4     87
# 4.6     78
# 4.9     61
# 2.3     47
# 4.7     42
# 2.2     27
# 4.8     25
# 2.1     15
# 2.0      7
# 1.9      2
# 1.8      1
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
figure,ax=plt.subplots(figsize=(12,5))
sns.countplot(x="Aggregate rating",data=dataset,ax=ax)
plt.savefig("rating.png")
plt.show()

# %%
dataset["Aggregate rating"].value_counts().plot(kind="pie")
plt.show()

# %%
topdata=dataset.sort_values(by=["Votes","Aggregate rating"],ascending=False)
topdata.head(5)
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 720           51705                       Toit             1  Bangalore
# 727           51040                   Truffles             1  Bangalore
# 3374         308322           Hauz Khas Social             1  New Delhi
# 2074          20404                  Peter Cat             1    Kolkata
# 731           56618  AB's - Absolute Barbecues             1  Bangalore
#
#                                                 Address  \
# 720   298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# 727   28, 4th 'B' Cross, Koramangala 5th Block, Bang...
# 3374             9-A & 12, Hauz Khas Village, New Delhi
# 2074        18A, Park Street, Park Street Area, Kolkata
# 731   90/4, 3rd Floor, Outer Ring Road, Munnekollaly...
#
#                    Locality                  Locality Verbose  Longitude  \
# 720             Indiranagar            Indiranagar, Bangalore  77.640709
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
data=dataset[["Longitude","Latitude"]]
data.head(4)
# Out:
#     Longitude   Latitude
# 0  121.027535  14.565443
# 1  121.014101  14.553708
# 2  121.056831  14.581404
# 3  121.056475  14.585318

# %%
distortions=[]
k=range(1,25)
for i in k:
    model=KMeans(n_clusters=i)
    model.fit(data)
    distortions.append(model.inertia_)

# %%
fig,ax=plt.subplots(figsize=(12,6))
plt.plot(k,distortions,marker="o")
plt.xlabel("K")
plt.ylabel("Distortions")
plt.show()

# %%
sil=[]
kmax=50
for k in range(2,kmax+1):
    model=KMeans(n_clusters=k).fit(data)
    labels=model.labels_
    sil.append(silhouette_score(data,labels,metric="euclidean"))

# %%
sil
# Out:
# [0.9008355338188367,
#  0.9105812454216888,
#  0.9221873843399252,
#  0.9262561797962106,
#  0.9117590039242686,
#  0.9319617481027669,
#  0.8740082173145711,
#  0.8877072411489303,
#  0.9167775140433106,
#  0.9050683645046846,
#  0.9182852363228564,
#  0.9032404326024018,
#  0.9088849019347477,
#  0.9122968749928015,
#  0.9049466530713742,
#  0.9094349072719683,
#  0.9215831951653565,
#  0.9232853121242613,
#  0.9162152337113381,
#  0.9209355295406877,
#  0.9244783969933034,
#  0.9104639919291607,
#  0.9069794093027599,
#  0.9135617446498969,
#  0.903629099401651,
#  0.899674100140632,
#  0.8741603889929653,
#  0.9159687176418952,
#  0.9013291415104367,
#  0.8989617815917543,
#  0.8955351696165985,
#  0.9022117886096009,
#  0.9006402354025441,
#  0.9020034700194975,
#  0.8948757389459959,
#  0.9030274041941938,
#  0.9005052028898586,
#  0.8868386330110135,
#  0.891260905145383,
#  0.8980757835016714,
#  0.8891844527460799,
#  0.41556013511902046,
#  0.8892619232870262,
# ...

# %%
model=KMeans(n_clusters=5,init="k-means++")
model.fit(data)
y=model.labels_
print("k=5","silhouette score:",silhouette_score(data,y,metric="euclidean"))
# Out:
# k=5 silhouette score: 0.9262561797962106

# %%
topdata["cluster"]=model.predict(topdata[["Longitude","Latitude"]])

# %%
# def recomend_restaurants(df,longitude,latitude):
#     cluster=model.predict(pd.DataFrame([longitude,latitude],columns=["Longitude","Latitude"]).reshape(1,-1))[0]
#     print(cluster)
#     return df[df["cluster"]==cluster].iloc[0:5][["Restaurant Name","Longitude","latitude"]]

# %%
def recomend_restaurants(df, longitude, latitude):
    location = pd.DataFrame([[longitude, latitude]], columns=["Longitude", "Latitude"])
    cluster = model.predict(location)[0]
    print("Predicted Cluster: ",cluster)
    return df[df["cluster"] == cluster].iloc[0:5][["Restaurant Name", "Longitude", "Latitude"]]

# %%
recomend_restaurants(topdata,77.699386,12.949934).reset_index(drop=True)
# Out:
# Predicted Cluster:  0
#              Restaurant Name  Longitude   Latitude
# 0                       Toit  77.640709  12.979166
# 1                   Truffles  77.614293  12.933298
# 2           Hauz Khas Social  77.194471  28.554285
# 3                  Peter Cat  88.352885  22.552672
# 4  AB's - Absolute Barbecues  77.699386  12.949934
